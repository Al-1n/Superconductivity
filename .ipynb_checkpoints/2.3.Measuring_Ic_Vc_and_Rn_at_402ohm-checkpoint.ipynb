# %% [markdown]
# # Measuring the Josephson Current, the gap voltage and the normal state resistance at 402ohm
# ** **
#  * This project uses the lmfit package. Lmfit provides curve fiting using non-linear least squares minimization and was developed by Matt Newville: https://github.com/newville.

# %% [markdown]
# ## Install and import libraries

# %%
#uncomment the following line to install lmfit
#!pip install lmfit

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from lmfit.models import LinearModel
import math

# %% [markdown]
# ## Data

# %%
#Load the data
df = pd.read_csv("./Data/402_one_pass.csv", sep = " ", header = None)

#Preview the data
df.head()
# Out:
#        0        1        2
# 0 -7.866 -61.4747  0.00311
# 1 -7.725 -59.5667  0.00301
# 2 -7.358 -56.8905  0.00288
# 3 -7.040 -54.1489  0.00274
# 4 -6.694 -51.4086  0.00261

# %% [markdown]
# ## Data wrangling

# %%
#Focus on the positive side of the graph
df = df[(df[0] >= 0.268)]

#Preview the subset
df.head()
# Out:
#         0        1        2
# 30  0.268   3.3406  0.00020
# 31  1.822   5.2718  0.00030
# 32  1.878   6.9896  0.00038
# 33  1.921   8.7230  0.00047
# 34  1.935  10.6706  0.00057

# %%
#Ascribe the columns to the V and I varibles 
V = list(df[0])
I = list(df[1])

#Preview the data
print("V = ", V)
print("I = ", I )
# Out:
# V =  [0.268, 1.822, 1.878, 1.921, 1.935, 2.005, 2.161, 2.401, 2.613, 2.839, 3.065, 3.305, 3.587, 3.827, 4.081, 4.322, 4.59, 4.894, 5.134, 5.48, 5.762, 6.045, 6.306, 6.652, 6.913, 7.294, 7.577, 7.93, 8.241, 8.015, 7.824, 7.591, 7.379, 7.196, 7.019, 6.814, 6.616, 6.419, 6.256, 6.045, 5.861, 5.649, 5.473, 5.331, 5.141, 4.957, 4.802, 4.618, 4.435, 4.307, 4.11, 3.968, 3.785, 3.644, 3.495, 3.333, 3.213, 3.072, 2.909, 2.761, 2.613, 2.486, 2.309, 2.147, 2.048, 2.02, 2.013, 1.977, 1.977, 1.956, 1.928, 1.794, 0.96]
# I =  [3.3406, 5.2718, 6.9896, 8.723, 10.6706, 12.5383, 14.3584, 16.0856, 18.124, 20.1391, 22.011, 24.1905, 25.9294, 28.0974, 30.133, 32.5615, 34.5207, 36.9936, 38.9289, 41.2742, 43.4797, 46.1204, 48.3811, 50.7742, 53.0826, 55.5098, 57.7753, 60.4631, 62.294, 60.5279, 59.0155, 57.3762, 56.0951, 54.5063, 53.0192, 51.4024, 49.9801, 48.4016, 46.8824, 45.3857, 44.0691, 42.4789, 41.1507, 39.5176, 38.3122, 36.999, 35.415, 34.2437, 32.8657, 31.5758, 30.1821, 28.8982, 27.5134, 26.1661, 24.9478, 23.7151, 22.3234, 21.1903, 19.8901, 18.7059, 17.4439, 16.235, 14.9792, 13.8843, 12.61, 11.5171, 10.2299, 9.2257, 7.9698, 6.9452, 5.6081, 4.5979, 3.5296]

# %%
#Identify the index of an arbitrary upper limit to enhance the plots 
V.index(4.894)
# Out:
# 17

# %%
#Remove the data above the chosen upper limit to enhance the view and focus on the single forward pass
V = np.array(V[0:15])

I = np.array(I[0:15])

#Preview the new subsets
print("V = ", V)
print("I = ", I)
# Out:
# V =  [0.268 1.822 1.878 1.921 1.935 2.005 2.161 2.401 2.613 2.839 3.065 3.305
#  3.587 3.827 4.081]
# I =  [ 3.3406  5.2718  6.9896  8.723  10.6706 12.5383 14.3584 16.0856 18.124
#  20.1391 22.011  24.1905 25.9294 28.0974 30.133 ]

# %%
#Uncomment the line below to make the graph interactive
#%matplotlib widget

#Preview the data
sns.relplot(x = V, y = I, kind = "line")

# %%
#Uncomment the line below to make the graph interactive
#%matplotlib widget

#Set figure size
plt.figure(figsize=(16,10))

#Take the second derivatove of the data
d2I_dV2 = np.gradient(np.gradient(I, V), V)

# Set a threshold to identify inflection points
threshold = 0.2  # Adjust this threshold as needed
inflection_points = V[d2I_dV2 > threshold]

# Create a line plot using seaborn
sns.lineplot(x=V, y=I, label='Data')
sns.lineplot(x=V, y=I, label='Data')

# Annotate inflection points on the graph
for point in inflection_points:
    plt.annotate(f'Inflection Point\n(V={point:.3f})\n(I = {np.interp(point, V, I):3f})', xy=(point, np.interp(point, V, I)),
                 xytext=(point -1, np.interp(point, V, I) + 5),
                 arrowprops={'facecolor': 'red', 'shrink': 0.05})

# Set plot labels and title
plt.xlabel('V')
plt.ylabel('I')
plt.title('Inflection Points Detection')

# Show the plot
plt.show()

# %%
#Preview the inflection points array
inflection_points
# Out:
# array([0.268, 1.822, 1.878, 1.921, 1.935, 2.613, 3.587, 3.827])

# %% [markdown]
# ### Clear the graph above to focus on Ic and Vc

# %%
#Uncomment the line below to make the graph interactive
#%matplotlib widget

#Set figure size
plt.figure(figsize=(9,6))

#Take the second derivative of the data
d2I_dV2 = np.gradient(np.gradient(I, V), V)

# Set a threshold to identify inflection points
threshold = 0.5  # Adjust this threshold as needed
inflection_points = V[d2I_dV2 > threshold]

# Create a line plot using seaborn
sns.lineplot(x=V, y=I, label='Data', color = "orange")

# Annotate inflection points on the graph
for idx, point in enumerate(inflection_points):
    if idx in [1, 4]:
        plt.annotate(f'Inflection Point\n(V={point:.3f}mV)\n(I = {np.interp(point, V, I):3f}$\mu A$)', 
                     xy=(point, np.interp(point, V, I)),
                     xytext=(point - 1, np.interp(point, V, I) + 5),
                     arrowprops={'facecolor': 'red', 'shrink': 0.05})


# Set plot labels and title
plt.xlabel('V')
plt.ylabel('I')
plt.title('Inflection Points Detection')

# Show the plot
plt.show()

# %% [markdown]
# # Estimating the normal state resistance (Rn)

# %%
#Preview the main dataset
print(list(df[0]))
# Out:
# [0.268, 1.822, 1.878, 1.921, 1.935, 2.005, 2.161, 2.401, 2.613, 2.839, 3.065, 3.305, 3.587, 3.827, 4.081, 4.322, 4.59, 4.894, 5.134, 5.48, 5.762, 6.045, 6.306, 6.652, 6.913, 7.294, 7.577, 7.93, 8.241, 8.015, 7.824, 7.591, 7.379, 7.196, 7.019, 6.814, 6.616, 6.419, 6.256, 6.045, 5.861, 5.649, 5.473, 5.331, 5.141, 4.957, 4.802, 4.618, 4.435, 4.307, 4.11, 3.968, 3.785, 3.644, 3.495, 3.333, 3.213, 3.072, 2.909, 2.761, 2.613, 2.486, 2.309, 2.147, 2.048, 2.02, 2.013, 1.977, 1.977, 1.956, 1.928, 1.794, 0.96]

# %%
#The dataset includes points from two complete sweeps
#Identify the index of the approximate limits of the normal state on the positive side of the graph 
print(list(df[0]).index(1.935))
print(list(df[0]).index(df[0].max()))
# Out:
# 4
# 28

# %%
#Select data from the first pass
V_n = np.array(df[0][4:28])
I_n = np.array(df[1][4:28])

#Preview the data
print(V_n)
print(I_n)
# Out:
# [1.935 2.005 2.161 2.401 2.613 2.839 3.065 3.305 3.587 3.827 4.081 4.322
#  4.59  4.894 5.134 5.48  5.762 6.045 6.306 6.652 6.913 7.294 7.577 7.93 ]
# [10.6706 12.5383 14.3584 16.0856 18.124  20.1391 22.011  24.1905 25.9294
#  28.0974 30.133  32.5615 34.5207 36.9936 38.9289 41.2742 43.4797 46.1204
#  48.3811 50.7742 53.0826 55.5098 57.7753 60.4631]

# %% [markdown]
# ## Define the model and fit the data

# %%
#Define the variables and convert to Volts and Amps
x = V_n / 0.001
y = I_n / 0.000001

#Use builtin NameModel, specify prefix for each:
mod = LinearModel(prefix='') 

#Set the initial parameters to 'guess' mode
pars  = mod.guess(y, x = x)

#Fit with weights=1/yerr
result = mod.fit(y, pars, x = x, weights= 1. / (y * 0.0318))

#Print the fit results
print(result.fit_report())
# Out:
# [[Model]]
#     Model(linear)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 7
#     # data points      = 24
#     # variables        = 2
#     chi-square         = 22.0995672
#     reduced chi-square = 1.00452578
#     Akaike info crit   = 2.02010067
#     Bayesian info crit = 4.37620833
#     R-squared          = 1.00000000
# [[Variables]]
#     slope:      8395.88321 +/- 112.738379 (1.34%) (init = 8124.482)
#     intercept: -4379065.70 +/- 366631.037 (8.37%) (init = -3224332)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(slope, intercept) = -0.9097

# %% [markdown]
# ## Plot the model

# %%
#Set the figure size
plt.figure(figsize = (9,6))

#Plot the data and the model
plt.scatter(x, y, linewidth=2)
plt.plot(x, result.best_fit, 'r-', linewidth=2.5)

# Set plot labels and title
plt.xlabel('V ($V$)')
plt.ylabel('I ($A$)')
plt.title('Normal State IVC')

#Show the plot
plt.show()

# %% [markdown]
# # Calculating the theoretical Ic and V_gap
#
# ![](./img/Ic_formula.png)

# %%
#Access the model parameters
varys = result.params.valuesdict()

varys
# Out:
# {'slope': 8395.883205536935, 'intercept': -4379065.700491861}

# %%
#The slope is equal to 1 / R 
R_n = 1 / varys.get("slope")

print('Normal state resistance: R_n = ', round(R_n, 6), 'Ohm')
# Out:
# Normal state resistance: R_n =  0.000119 Ohm

# %%
#Define the terms for the strong and weak coupling formulas 
t_c = 9.25 #critical temperature
delta_0 = 2.25288819E-22 # from 1.764 * k_B * t_c,  [check eqn. 1 on the report paper] 
t = 7.38123653 #from the calibration curve in notebook 2
e = 1.6022E-19 #elementay charge
pi = 3.14159265358979323846264338327950 
t_red = t / t_c #the reduced temperature
k_B = 1.3807E-23 #Boltzmann constant
R_n = 1 / varys.get("slope") #from the slope of the IVC


#weak coupling formula

delta_weak = delta_0 * 1.74 * math.sqrt(1.0 - t_red)

E_weak = delta_weak * 2

V_weak = (E_weak / e) * 1000

#The Ambegaokar-Baratoff formula
Ic_weak = (pi / 2) * (delta_weak / (e * R_n)) * math.tanh(delta_weak / (2 * k_B * t))


#strong coupling approximation

delta_strong = (delta_0) * math.sqrt(math.cos((pi * t_red**2)  / 2 )) 

E_strong = delta_strong * 2

V_strong = (E_strong / e) * 1000

#The Ambegaokar-Baratoff formula
Ic_strong = (pi / 2) * (delta_strong / (e * R_n)) * math.tanh(delta_strong / (2 * k_B * t))


#Print the results
print('Temperature =', t, 'K')
print('-----------------------------')
print('-----------------------------')
                         
print('Weak Coupling Formula')
print('-----------------------------')


print('delta_t =', delta_weak, 'J')
print('Gap Energy =', E_weak, 'J')
print('Gap Voltage =', V_weak, 'mV')
print('Josephson Current =', Ic_weak, 'uA')
print('______________________________')
print('______________________________')
print('------------------------------')
print('Strong Coupling Approximation')
print('------------------------------')

print('delta_t =', delta_strong, 'J')
print('Gap Energy = ', E_strong, 'J')
print('Gap Voltage =', V_strong, 'mV')
print('Josephson Current =', Ic_strong, 'uA')
print('________________________________')
print('________________________________')
print('________________________________')
# Out:
# Temperature = 7.38123653 K
# -----------------------------
# -----------------------------
# Weak Coupling Formula
# -----------------------------
# delta_t = 1.7619565250962866e-22 J
# Gap Energy = 3.523913050192573e-22 J
# Gap Voltage = 2.199421451874031 mV
# Josephson Current = 10.131088057326222 uA
# ______________________________
# ______________________________
# ------------------------------
# Strong Coupling Approximation
# ------------------------------
# delta_t = 1.6557101604313494e-22 J
# Gap Energy =  3.311420320862699e-22 J
# Gap Voltage = 2.066795856236861 mV
# Josephson Current = 9.143029962049823 uA
# ________________________________
# ________________________________
# ________________________________

# %%
#Add all the collected results to a dictionary
Josephson_data = {"Ic" : np.interp(inflection_points[4], V, I) , "Ic_weak" : Ic_weak, "Ic_strong" : Ic_strong, "V_gap" : inflection_points[1], "Vg_weak" : V_weak, "Vg_strong" : V_strong, "Temp" : t}

#Preview the newly created row of data
print(Josephson_data)
# Out:
# {'Ic': 10.6706, 'Ic_weak': 10.131088057326222, 'Ic_strong': 9.143029962049823, 'V_gap': 1.822, 'Vg_weak': 2.199421451874031, 'Vg_strong': 2.066795856236861, 'Temp': 7.38123653}

# %% [markdown]
# ## Export the results to a csv file

# %%
# import csv

# with open(r'./Data/Josephson_data.csv', 'a', newline='') as csvfile:
#     fieldnames = ['Ic','Ic_weak', 'Ic_strong', 'V_gap', 'Vg_weak', 'Vg_strong', 'Temp']
#     writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

#     writer.writerow(Josephson_data)

# %% [markdown]
# ## Author
# ** **
#
# ### <a href="https://www.linkedin.com/in/alin-airinei/">Alin Airinei</a>
